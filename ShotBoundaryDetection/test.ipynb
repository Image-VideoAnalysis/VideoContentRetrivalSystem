# %%
import torch
from TransNetV2.transnetv2_pytorch import TransNetV2

model = TransNetV2()
state_dict = torch.load("TransNetV2/transnetv2-pytorch-weights.pth")
model.load_state_dict(state_dict)
model.eval()
# Out:
# TransNetV2(
#   (SDDCNN): ModuleList(
#     (0): StackedDDCNNV2(
#       (DDCNN): ModuleList(
#         (0): DilatedDCNNV2(
#           (Conv3D_1): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(3, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             )
#           )
#           (Conv3D_2): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(3, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), dilation=(2, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_4): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(3, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(4, 0, 0), dilation=(4, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_8): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(3, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(8, 0, 0), dilation=(8, 1, 1), bias=False)
#             )
#           )
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): DilatedDCNNV2(
#           (Conv3D_1): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             )
#           )
#           (Conv3D_2): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), dilation=(2, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_4): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(4, 0, 0), dilation=(4, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_8): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 32, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(32, 16, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(8, 0, 0), dilation=(8, 1, 1), bias=False)
#             )
#           )
#           (bn): BatchNorm3d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (pool): AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0)
#     )
#     (1): StackedDDCNNV2(
#       (DDCNN): ModuleList(
#         (0): DilatedDCNNV2(
#           (Conv3D_1): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             )
#           )
#           (Conv3D_2): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), dilation=(2, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_4): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(4, 0, 0), dilation=(4, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_8): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(64, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(8, 0, 0), dilation=(8, 1, 1), bias=False)
#             )
#           )
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): DilatedDCNNV2(
#           (Conv3D_1): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             )
#           )
#           (Conv3D_2): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), dilation=(2, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_4): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(4, 0, 0), dilation=(4, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_8): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 64, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(64, 32, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(8, 0, 0), dilation=(8, 1, 1), bias=False)
#             )
#           )
#           (bn): BatchNorm3d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (pool): AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0)
#     )
#     (2): StackedDDCNNV2(
#       (DDCNN): ModuleList(
#         (0): DilatedDCNNV2(
#           (Conv3D_1): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             )
#           )
#           (Conv3D_2): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), dilation=(2, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_4): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(4, 0, 0), dilation=(4, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_8): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(128, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(8, 0, 0), dilation=(8, 1, 1), bias=False)
#             )
#           )
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (1): DilatedDCNNV2(
#           (Conv3D_1): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(256, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(1, 0, 0), bias=False)
#             )
#           )
#           (Conv3D_2): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(256, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(2, 0, 0), dilation=(2, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_4): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(256, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(4, 0, 0), dilation=(4, 1, 1), bias=False)
#             )
#           )
#           (Conv3D_8): Conv3DConfigurable(
#             (layers): ModuleList(
#               (0): Conv3d(256, 128, kernel_size=(1, 3, 3), stride=(1, 1, 1), padding=(0, 1, 1), bias=False)
#               (1): Conv3d(128, 64, kernel_size=(3, 1, 1), stride=(1, 1, 1), padding=(8, 0, 0), dilation=(8, 1, 1), bias=False)
#             )
#           )
#           (bn): BatchNorm3d(256, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (pool): AvgPool3d(kernel_size=(1, 2, 2), stride=(1, 2, 2), padding=0)
#     )
#   )
#   (frame_sim_layer): FrameSimilarity(
#     (projection): Linear(in_features=448, out_features=128, bias=True)
#     (fc): Linear(in_features=101, out_features=128, bias=True)
#   )
#   (color_hist_layer): ColorHistograms(
#     (fc): Linear(in_features=101, out_features=128, bias=True)
#   )
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc1): Linear(in_features=4864, out_features=1024, bias=True)
#   (cls_layer1): Linear(in_features=1024, out_features=1, bias=True)
#   (cls_layer2): Linear(in_features=1024, out_features=1, bias=True)
# )
